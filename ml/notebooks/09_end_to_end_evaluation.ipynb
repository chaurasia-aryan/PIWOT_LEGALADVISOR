# %% [markdown]
# # Notebook 09: End-to-End Evaluation & Benchmark Matrix
#
# This notebook runs the complete multi-page contract pipeline on test contracts, evaluates metrics across all modules, and summarizes model performance.

# %%
import os
import sys
import json
import pandas as pd

REPORTS_PATH = os.path.abspath(os.path.join("..", "reports", "final_metrics.json"))
with open(REPORTS_PATH, "r", encoding="utf-8") as f:
    metrics = json.load(f)

print(json.dumps(metrics, indent=2))
